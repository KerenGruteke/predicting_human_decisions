# %%
import pandas as pd
from pathlib import Path

src_path = Path.cwd().parent
print(src_path)

hab22 = pd.read_csv(src_path / 'data/hab22/HAB22.csv', engine='pyarrow')
hab22
# Out:
# /data/home/gkeren/predicting_human_decisions/src
#                     dataset   Type                                   task_id  \
# 0                 Erev17app  Mixed                Erev17app_-1_1_-1_0_0.5_-2
# 1                 Erev17app  Mixed                Erev17app_-1_1_-1_0_0.5_-2
# 2                 Erev17app  Mixed                Erev17app_-1_1_-1_0_0.5_-2
# 3                 Erev17app  Mixed                Erev17app_-1_1_-1_0_0.5_-2
# 4                 Erev17app  Mixed                Erev17app_-1_1_-1_0_0.5_-2
# ...                     ...    ...                                       ...
# 70785  Stewart15_1C_uniform  Gains  Stewart15_1C_uniform_500_0.6_0_400_0.8_0
# 70786  Stewart15_1C_uniform  Gains  Stewart15_1C_uniform_200_0.4_0_100_0.8_0
# 70787  Stewart15_1C_uniform  Gains  Stewart15_1C_uniform_400_0.8_0_200_1_200
# 70788  Stewart15_1C_uniform  Gains  Stewart15_1C_uniform_400_0.2_0_300_1_300
# 70789  Stewart15_1C_uniform  Gains  Stewart15_1C_uniform_400_0.4_0_100_1_100
#
#           Ha  pHa   La     Hb  pHb     Lb  crossValidation_id  ...  \
# 0       -1.0  1.0 -1.0    0.0  0.5   -2.0                   1  ...
# 1       -1.0  1.0 -1.0    0.0  0.5   -2.0                   1  ...
# 2       -1.0  1.0 -1.0    0.0  0.5   -2.0                   1  ...
# 3       -1.0  1.0 -1.0    0.0  0.5   -2.0                   1  ...
# 4       -1.0  1.0 -1.0    0.0  0.5   -2.0                   1  ...
# ...      ...  ...  ...    ...  ...    ...                 ...  ...
# 70785  500.0  0.6  0.0  400.0  0.8    0.0                  10  ...
# 70786  200.0  0.4  0.0  100.0  0.8    0.0                  10  ...
# 70787  400.0  0.8  0.0  200.0  1.0  200.0                  10  ...
# 70788  400.0  0.2  0.0  300.0  1.0  300.0                  10  ...
# 70789  400.0  0.4  0.0  100.0  1.0  100.0                  10  ...
#
#        pBbet_Unbiased1  pBbet_UnbiasedFB  pBbet_Uniform  pBbet_Sign1  \
# 0              -0.0078           0.00140        0.00460      0.50360
# 1              -0.0078           0.00140        0.00460      0.50360
# 2              -0.0078           0.00140        0.00460      0.50360
# 3              -0.0078           0.00140        0.00460      0.50360
# 4              -0.0078           0.00140        0.00460      0.50360
# ...                ...               ...            ...          ...
# 70785          -0.4058          -0.27790       -0.49915      0.19735
# 70786          -0.0041           0.08155       -0.50330      0.40385
# 70787          -0.6011          -0.60630        0.01190      0.20435
# 70788           0.6068           0.59150        0.00460      0.79635
# 70789           0.1854           0.19390       -0.01670      0.59900
#
#        pBbet_SignFB  Dom  diffBEV0  diffBEVfb  diffSignEV  BEASTpred
# 0           0.50030    0       0.0        0.0         1.0   0.527500
# 1           0.50030    0       0.0        0.0         1.0   0.527500
# 2           0.50030    0       0.0        0.0         1.0   0.527500
# 3           0.50030    0       0.0        0.0         1.0   0.527500
# 4           0.50030    0       0.0        0.0         1.0   0.527500
# ...             ...  ...       ...        ...         ...        ...
# 70785       0.20865    0      20.0       20.0       100.0   0.455417
# 70786       0.39900    0       0.0        0.0        80.0   0.452917
# 70787       0.19790    0    -120.0     -120.0        80.0   0.242417
# 70788       0.79990    0     220.0      220.0       320.0   1.000000
# 70789       0.59805    0     -60.0      -60.0       240.0   0.513500
#
# [70790 rows x 90 columns]

# %%
cpc18 = pd.read_csv(src_path / 'data/cpc18/rawData_Comp_All.csv', engine='pyarrow')
cpc18
# Out:
#         SubjID  Location Gender  Age  Set Condition  GameID  Ha  pHa  La  ...  \
# 0        80001   Rehovot      F   23    8    ByProb     211  96  0.2   3  ...
# 1        80001   Rehovot      F   23    8    ByProb     211  96  0.2   3  ...
# 2        80001   Rehovot      F   23    8    ByProb     211  96  0.2   3  ...
# 3        80001   Rehovot      F   23    8    ByProb     211  96  0.2   3  ...
# 4        80001   Rehovot      F   23    8    ByProb     211  96  0.2   3  ...
# ...        ...       ...    ...  ...  ...       ...     ...  ..  ...  ..  ...
# 179995   91126  Technion      F   28    9    ByProb     252  29  1.0  29  ...
# 179996   91126  Technion      F   28    9    ByProb     252  29  1.0  29  ...
# 179997   91126  Technion      F   28    9    ByProb     252  29  1.0  29  ...
# 179998   91126  Technion      F   28    9    ByProb     252  29  1.0  29  ...
# 179999   91126  Technion      F   28    9    ByProb     252  29  1.0  29  ...
#
#        Trial  Button  B  Payoff  Forgone     RT  Apay  Bpay  Feedback  block
# 0          1       L  1      59        3  20809     3    59         0      1
# 1          2       L  1      59        3   6282     3    59         0      1
# 2          3       L  1      59        3   3242     3    59         0      1
# 3          4       L  1     -19        3   3557     3   -19         0      1
# 4          5       L  1     -19        3   3944     3   -19         0      1
# ...      ...     ... ..     ...      ...    ...   ...   ...       ...    ...
# 179995    21       L  0      29       17    490    29    17         1      5
# 179996    22       R  1      17       29    474    29    17         1      5
# 179997    23       R  1      17       29    486    29    17         1      5
# 179998    24       L  0      29       17    503    29    17         1      5
# 179999    25       R  1      17       29   1042    29    17         1      5
#
# [180000 rows x 30 columns]

# %%
c13k = pd.read_csv(src_path / 'data/choices13k/c13k_selections.csv', engine='pyarrow')
c13k
# Out:
#        Problem  Feedback   n  Block  Ha  pHa  La  Hb   pHb  Lb  ...  LotNumB  \
# 0         2258      True  16      5  16  1.0  16  19  0.80 -37  ...        4
# 1            2      True  15      4  14  0.6 -18   8  0.25  -5  ...        1
# 2        10047      True  16      2  -1  1.0  -1   4  0.60 -29  ...        8
# 3         4291      True  15      5  -6  1.0  -6   0  0.50 -33  ...        6
# 4            5     False  15      1  26  1.0  26  45  0.75 -36  ...        5
# ...        ...       ...  ..    ...  ..  ...  ..  ..   ...  ..  ...      ...
# 14563    13002      True  15      3  30  1.0  30  42  0.80   0  ...        1
# 14564    10945      True  16      2  15  1.0  15  15  0.80  -1  ...        1
# 14565    11219      True  15      2   8  1.0   8   8  0.50  -1  ...        1
# 14566    12253      True  15      5   3  1.0   3  -2  0.80  -4  ...        8
# 14567    13006      True  15      3  25  0.8  25  70  0.50  -4  ...        1
#
#          Amb  Corr     bRate  bRate_std  BEAST_1  BEAST_2  BEAST_3  BEAST_4  \
# 0      False     0  0.675000   0.356838   0.0718   0.0907   0.0931   0.0975
# 1       True    -1  0.493333   0.413118   0.5421   0.4440   0.4109   0.4105
# 2      False     0  0.775000   0.308761   0.2219   0.1978   0.1521   0.1367
# 3      False     0  0.666667   0.390360   0.1047   0.0936   0.0743   0.0645
# 4      False     0  0.586667   0.450185   0.4088   0.5008   0.5145   0.5199
# ...      ...   ...       ...        ...      ...      ...      ...      ...
# 14563   True     0  0.367619   0.302731   0.2132   0.4338   0.5099   0.5382
# 14564  False     0  0.000000   0.000000   0.0000   0.0000   0.0000   0.0000
# 14565  False     0  0.000000   0.000000   0.0000   0.0000   0.0000   0.0000
# 14566  False     0  0.000000   0.000000   0.0000   0.0000   0.0000   0.0000
# 14567   True     0  0.626667   0.361478   0.3830   0.4715   0.5335   0.5555
#
#        BEAST_5
# 0       0.0907
# 1       0.3995
# 2       0.1349
# 3       0.0661
# 4       0.5181
# ...        ...
# 14563   0.5690
# 14564   0.0000
# 14565   0.0000
# 14566   0.0000
# 14567   0.5606
#
# [14568 rows x 21 columns]
